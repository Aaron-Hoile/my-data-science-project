# %% [raw]
# @notebook{train-register-deploy-other-frameworks.ipynb,
#     title: Train, Register, and Deploy a Generic Model,
#     summary: Train, register, and deploy a generic model,
#     developed_on: generalml_p312_cpu_x86_64_v1,
#     keywords: generic model, deploy model, register model, train model,
#     license: Universal Permissive License v 1.0
# }

# %%
# Upgrade Oracle ADS to pick up latest features and maintain compatibility with Oracle Cloud Infrastructure.

# !pip install -U oracle-ads
# Out:
# Requirement already satisfied: oracle-ads in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (2.15.1)
# Collecting oracle-ads
#   Downloading oracle_ads-2.15.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (6.0.2)
# Requirement already satisfied: asteval>=0.9.25 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (1.0.8+a.oracle00001)
# Requirement already satisfied: cerberus>=1.3.4 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (1.3.8+a.oracle00001)
# Requirement already satisfied: cloudpickle>=1.6.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (3.1.2+a.oracle00001)
# Requirement already satisfied: fsspec>=0.8.7 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (2026.4.0+a.oracle00001)
# Requirement already satisfied: gitpython>=3.1.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (3.1.50)
# Requirement already satisfied: jinja2>=2.11.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (3.1.6+a.oracle00001)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (3.10.9)
# Requirement already satisfied: numpy>=1.19.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (1.26.4)
# Requirement already satisfied: oci>=2.148.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (2.174.0)
# Requirement already satisfied: ocifs>=1.1.3 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (1.3.4)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (2.3.3)
# Requirement already satisfied: psutil>=5.7.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (7.2.2)
# Requirement already satisfied: python_jsonschema_objects>=0.3.13 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (0.5.7)
# Requirement already satisfied: requests in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (2.34.2)
# Requirement already satisfied: scikit-learn>=1.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (1.5.2)
# Requirement already satisfied: tabulate>=0.8.9 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (0.10.0+a.oracle00002)
# Requirement already satisfied: tqdm>=4.59.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (4.67.3+a.oracle00001)
# Requirement already satisfied: pydantic>=2.6.3 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (2.13.4+a.oracle00002)
# Requirement already satisfied: tenacity in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (9.1.4+a.oracle00001)
# Requirement already satisfied: httpx in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (0.28.1+a.oracle00001)
# Requirement already satisfied: packaging>=21.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oracle-ads) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.0->oracle-ads) (2.9.0.post0+a.oracle00005)
# Requirement already satisfied: pytz>=2020.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.0->oracle-ads) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.2.0->oracle-ads) (2026.2+a.oracle00001)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from gitpython>=3.1.2->oracle-ads) (4.0.12+a.oracle00001)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.2->oracle-ads) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from jinja2>=2.11.2->oracle-ads) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from matplotlib>=3.1.3->oracle-ads) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from matplotlib>=3.1.3->oracle-ads) (0.12.1+a.oracle00007)
# Requirement already satisfied: fonttools>=4.22.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from matplotlib>=3.1.3->oracle-ads) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from matplotlib>=3.1.3->oracle-ads) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from matplotlib>=3.1.3->oracle-ads) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from matplotlib>=3.1.3->oracle-ads) (3.3.2+a.oracle00002)
# Requirement already satisfied: certifi in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oci>=2.148.0->oracle-ads) (2025.11.12+a.oracle00002)
# Requirement already satisfied: cryptography<47.0.0,>=3.2.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oci>=2.148.0->oracle-ads) (46.0.7)
# Requirement already satisfied: pyOpenSSL<27.0.0,>=17.5.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oci>=2.148.0->oracle-ads) (26.2.0+a.oracle00001)
# Requirement already satisfied: urllib3>=2.6.3 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oci>=2.148.0->oracle-ads) (2.7.0+a.oracle00001)
# Requirement already satisfied: circuitbreaker<3.0.0,>=1.3.1 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from oci>=2.148.0->oracle-ads) (2.1.3)
# Requirement already satisfied: cffi>=2.0.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from cryptography<47.0.0,>=3.2.1->oci>=2.148.0->oracle-ads) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.9 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pyOpenSSL<27.0.0,>=17.5.0->oci>=2.148.0->oracle-ads) (4.15.0+a.oracle00002)
# Requirement already satisfied: six>=1.5 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->oracle-ads) (1.17.0)
# Requirement already satisfied: pycparser in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47.0.0,>=3.2.1->oci>=2.148.0->oracle-ads) (3.0+a.oracle00001)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pydantic>=2.6.3->oracle-ads) (0.7.0+a.oracle00001)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pydantic>=2.6.3->oracle-ads) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from pydantic>=2.6.3->oracle-ads) (0.4.2+a.oracle00001)
# Requirement already satisfied: inflection>=0.2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (0.5.1)
# Requirement already satisfied: Markdown>=2.4 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (3.10.2+a.oracle00004)
# Requirement already satisfied: jsonschema>=4.18 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (4.26.0+a.oracle00001)
# Requirement already satisfied: attrs>=22.2.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads) (26.1.0+a.oracle00001)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads) (2025.9.1+a.oracle00001)
# Requirement already satisfied: referencing>=0.28.4 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads) (0.37.0+a.oracle00001)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads) (0.30.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from scikit-learn>=1.0->oracle-ads) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from scikit-learn>=1.0->oracle-ads) (1.5.3+a.oracle00001)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from scikit-learn>=1.0->oracle-ads) (3.6.0+a.oracle00001)
# Requirement already satisfied: anyio in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from httpx->oracle-ads) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from httpx->oracle-ads) (1.0.9+a.oracle00001)
# Requirement already satisfied: idna in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from httpx->oracle-ads) (3.15)
# Requirement already satisfied: h11>=0.16 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from httpcore==1.*->httpx->oracle-ads) (0.16.0+a.oracle00001)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages (from requests->oracle-ads) (3.4.7)
# Downloading oracle_ads-2.15.2-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.2 MB/s  0:00:00 eta 0:00:010m
# Installing collected packages: oracle-ads
#   Attempting uninstall: oracle-ads
#     Found existing installation: oracle_ads 2.15.1
#     Uninstalling oracle_ads-2.15.1:
#       Successfully uninstalled oracle_ads-2.15.1
# Successfully installed oracle-ads-2.15.2

# %% [markdown]
# <font color=gray>Oracle Data Science service sample notebook.
#
# Copyright (c) 2022 Oracle, Inc.  All rights reserved.
# Licensed under the Universal Permissive License v 1.0 as shown at https://oss.oracle.com/licenses/upl.
# </font>
#
# ***
# # <font color=red>Train, Register, and Deploy a Generic Model</font>
# <p style="margin-left:10%; margin-right:10%;">by the <font color=teal> Oracle Cloud Infrastructure Data Science Service Team </font></p>
#
# ***
#
# ## Overview
#
# The notebook demonstrates how to to train, test, save and deploy an instance of the `GenericModel` class.
#
# The `GenericModel` class in Accelerated Data Science (ADS) allows you to rapidly get a model into production. The `.prepare()` method creates the model artifacts that are needed to deploy a functioning model without you having to configure it or write code, including the ability to customize the `score.py` file as needed. The model can be subsequently verified, saved, and deployed.
#
# Compatible conda pack: [General Machine Learning](https://docs.oracle.com/en-us/iaas/data-science/using/conda-gml-fam.htm) for CPU on Python 3.11 (version 1.0)
#
# ### Prequisites
#
# This notebook requires authorization to work with the OCI Data Science Service. Details can be found [here](https://accelerated-data-science.readthedocs.io/en/latest/user_guide/cli/authentication.html#). For the purposes of this notebook what is important to to know is that resource principals will be used absent api_key authentication.
#
# ---
#
# ## Contents
#
# * <a href='#intro'>Introduction</a>
# * <a href='#create'>Create a Generic Model</a>
# * <a href='#serialize'>Generic Framework Serialization</a>
#     * <a href='#serialize_genericmodel'>Create a GenericModel</a>
#     * <a href='#serialize_prepare'>Prepare</a>
#     * <a href='#serialize_verify'>Verify</a>
#     * <a href='#serialize_save'>Save</a>
#     * <a href='#serialize_deploy'>Deploy</a>
#     * <a href='#serialize_predict'>Predict</a>
# * <a href='#clean_up'>Clean Up</a>
# * <a href='#ref'>References</a>
#
# ---
#
# Datasets are provided as a convenience. Datasets are considered third-party content and are not considered materials under your agreement with Oracle.

# %%
import ads
import logging
import os
import random
import tempfile
import warnings

from ads.common.model_metadata import UseCaseType
from ads.model.generic_model import GenericModel
from numpy import array
from shutil import rmtree

logging.basicConfig(format="%(levelname)s:%(message)s", level=logging.ERROR)
warnings.filterwarnings("ignore")
# Out:
# /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages/oci/_vendor/requests/__init__.py:107: RequestsDependencyWarning: urllib3 (2.7.0+a.oracle00001) or chardet (4.0.0)/charset_normalizer (3.4.7) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /home/datascience/conda/generalml_p312_cpu_x86_64_v3/lib/python3.12/site-packages/requests/__init__.py:119: RequestsDependencyWarning: urllib3 (2.7.0+a.oracle00001) or chardet (None)/charset_normalizer (3.4.7) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# <a id='intro'></a>
# # Introduction
#
# In this notebook, you will create a custom model class called `Square`. It has one method, `.predict()`, that returns the predicted value. It is designed to demonstrate how to create your own custom model class and use the `GenericModel` class.
#
# The `.prepare()` method will store the model as a pickle file. It will also generate a generic `score.py` file that will load the pickle file and call the `predict()` method.

# %% [markdown]
# ### Authenticate
#
# Authentication to the OCI Data Science service is required. Here we default to resource principals.

# %%
ads.set_auth(auth="resource_principal")

# %% [markdown]
# <a id='create'></a>
# # Create a Generic Model
#
# The next cell creates a class and instantiates it such that you have a custom model. This toy model takes a collection of values and returns the square of the values. Since this is a parametric model with no parameters to learn, there is no need to train it.

# %%
class Square:
    def predict(self, x):
        import numpy as np

        x_array = np.array(x)
        return np.ndarray.tolist(x_array * x_array)


model = Square()

# %% [markdown]
# The next cell will sample random values. You then use the .predict() method to make predictions on the dataset.

# %%
random.seed(42)
X = random.sample(range(0, 100), 10)
model.predict(X)
# Out:
# [6561, 196, 9, 8836, 1225, 961, 784, 289, 169, 7396]

# %% [markdown]
# <a id='serialize'></a>
# # Generic Framework Serialization
#
# <a id='serialize_genericmodel'></a>
# ## Create a GenericModel
#
# The next cell creates a model artifact directory. This directory is used to store the artifacts that are needed to deploy the model. It also creates the `GenericModel` object.

# %%
artifact_dir = tempfile.mkdtemp()
print(f"Model artifact director: {artifact_dir}")
generic_model = GenericModel(estimator=model, artifact_dir=artifact_dir)
# Out:
# Model artifact director: /tmp/tmpmvj5h3xm
# WARNING:ads.common:Model input is serialized into a dictionary containing serialized input data and original data type information by default. Set `model_input_serializer` to choose a different input serializer.

# %% [markdown]
# The `.summary_status()` method shows the progress toward deploying the model.

# %%
generic_model.summary_status()
# Out:
#                                                                             Actions Needed
# Step      Status        Details
# initiate  Done          Initiated the model
# prepare() Available     Generated runtime.yaml
#                         Generated score.py
#                         Serialized model
#                         Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Not Available Local tested .predict from score.py
# save()    Not Available Conducted Introspect Test
#                         Uploaded artifact to model catalog
# deploy()  UNKNOWN       Deployed the model
# predict() Not Available Called deployment predict endpoint

# %% [markdown]
# <a id='serialize_prepare'></a>
# ## Prepare
#
# The prepare step is performed by the `.prepare()` method of the `GenericModel` class. It creates a number of customized files that are used to run the model once it is deployed. These include:
#
# * `input_schema.json`: A JSON file that defines the nature of the features of the `X_sample` data.
# * `output_schema.json`: A JSON file that defines the nature of the dependent variable in the `y_sample` data.
# * `runtime.yaml`: This file contains information that is needed to set up the runtime environment on the deployment server.
# * `score.py`: This script contains the `load_model()` and `predict()` functions. The `load_model()` function understands the format the model file was saved in, and loads it into memory. The `.predict()` method is used to make inferences in a deployed model.
#
# The `.prepare()` method requires the `model_file_name` parameter to define the name of the model file. By default, the model is stored in a pickle file. `as_onnx` provides an alternate way to save it in the ONNX format.
#
# To create the model artifacts, you use the `.prepare()` method
#
# * `conda_env` variable defines the slug of the conda environment that was used to train the model
#
#  Note that you can only pass in slug for service conda environment. For custom conda environment, you have to pass in the full path along with the `inference_python_version`.

# %%
conda_env = "generalml_p312_cpu_x86_64_v1"

generic_model.prepare(
    inference_conda_env=conda_env,
    training_conda_env=conda_env,
    use_case_type=UseCaseType.MULTINOMIAL_CLASSIFICATION,
    X_sample=X,
    y_sample=array(X) ** 2,
)
# Out:
#                                                                                                                                                                                                        ?, ?it/s]

# %% [markdown]
# The next cell uses the `.summary_status()` method to show you that the prepare step finished, and what tasks were completed:

# %%
generic_model.summary_status()
# Out:
#                                                                             Actions Needed
# Step      Status        Details
# initiate  Done          Initiated the model
# prepare() Done          Generated runtime.yaml
#                         Generated score.py
#                         Serialized model
#           Available     Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Not Available Local tested .predict from score.py
# save()    Not Available Conducted Introspect Test
#                         Uploaded artifact to model catalog
# deploy()  UNKNOWN       Deployed the model
# predict() Not Available Called deployment predict endpoint

# %% [markdown]
# The `.prepare()` method has created the following fully files. However, you can modify them to fit your specific needs.

# %%
os.listdir(artifact_dir)
# Out:
# ['.model-ignore',
#  'input_schema.json',
#  'model.pkl',
#  'score.py',
#  'runtime.yaml',
#  'output_schema.json']

# %% [markdown]
# Once the artifacts have been created, there are a number of attributes in the `GenericModel` object that provide metadata about the model. The `.runtime` attribute details the model deployment settings and model provenance data.

# %%
generic_model.runtime_info
# Out:
# model_artifact_version: '3.0'
# model_deployment:
#   inference_conda_env:
#     inference_env_path: oci://service-conda-packs@id19sfcrra6z/service_pack/cpu/General_Machine_Learning_for_CPUs_on_Python_3.12/1.0/generalml_p312_cpu_x86_64_v1
#     inference_env_slug: generalml_p312_cpu_x86_64_v1
#     inference_env_type: data_science
#     inference_python_version: '3.12'
# model_provenance:
#   project_ocid: ''
#   tenancy_ocid: ''
#   training_code:
#     artifact_directory: /tmp/tmpmvj5h3xm
#   training_compartment_ocid: ''
#   training_conda_env:
#     training_env_path: oci://service-conda-packs@id19sfcrra6z/service_pack/cpu/General_Machine_Learning_for_CPUs_on_Python_3.12/1.0/generalml_p312_cpu_x86_64_v1
#     training_env_slug: generalml_p312_cpu_x86_64_v1
#     training_env_type: data_science
#     training_python_version: '3.12'
#   training_region: ''
#   training_resource_ocid: ''
#   user_ocid: ''
#   vm_image_internal_id: ''

# %% [markdown]
# The `.schema_input` attribute provides metadata on the features that were used to train the model. You can use this information to determine what data must be provided to make model inferences. Each feature in the model has a section that defines the dtype, feature type, name, and if it is required. The metadata also includes the summary statistics associated with the feature type.

# %%
generic_model.schema_input
# Out:
# schema:
# - description: '0'
#   domain:
#     constraints: []
#     stats:
#       count: 10.0
#       lower quartile: 14.75
#       mean: 40.2
#       median: 29.5
#       sample maximum: 94.0
#       sample minimum: 3.0
#       standard deviation: 33.77309909117347
#       upper quartile: 69.5
#     values: Integer
#   dtype: int64
#   feature_type: Integer
#   name: 0
#   order: 0
#   required: true
# version: '1.1'

# %% [markdown]
# The `.metadata_custom` attribute provides custom metadata that contains information on the category of the metadata, description, key, and value:

# %%
generic_model.metadata_custom
# Out:
# data:
# - category: Other
#   description: The model file name.
#   has_artifact: false
#   key: ModelFileName
#   value: model.pkl
# - category: Training Environment
#   description: The conda environment type, can be published or datascience.
#   has_artifact: false
#   key: EnvironmentType
#   value: data_science
# - category: Training Environment
#   description: The slug name of the training conda environment.
#   has_artifact: false
#   key: SlugName
#   value: generalml_p312_cpu_x86_64_v1
# - category: Other
#   description: ''
#   has_artifact: false
#   key: ClientLibrary
#   value: ADS
# - category: Training Environment
#   description: The URI of the training conda environment.
#   has_artifact: false
#   key: CondaEnvironmentPath
#   value: oci://service-conda-packs@id19sfcrra6z/service_pack/cpu/General_Machine_Learning_for_CPUs_on_Python_3.12/1.0/generalml_p312_cpu_x86_64_v1
# - category: Training Environment
#   description: The list of files located in artifacts folder.
#   has_artifact: false
#   key: ModelArtifacts
#   value: .model-ignore, model.pkl, score.py, runtime.yaml
# - category: Training Profile
#   description: The model serialization format.
#   has_artifact: false
#   key: ModelSerializationFormat
#   value: pkl
# - category: Training Environment
#   description: The conda environment where the model was trained.
#   has_artifact: false
#   key: CondaEnvironment
#   value: oci://service-conda-packs@id19sfcrra6z/service_pack/cpu/General_Machine_Learning_for_CPUs_on_Python_3.12/1.0/generalml_p312_cpu_x86_64_v1

# %% [markdown]
# The `.metadata_provenance` contains information about the code and training data that was used to create the model. This information is most useful when a Git repository is being used to manage the code for training the model. This is considered a best practice because it allows you to do things like reproduce a model, perform forensic on the model, and so on.

# %%
generic_model.metadata_provenance
# Out:
# artifact_dir: null
# git_branch: null
# git_commit: null
# repository_url: null
# training_id: null
# training_script_path: null

# %% [markdown]
# The `.metadata_taxonomy` is a key-value store that has information about the classification or taxonomy of the model. This can include information such as the model framework, use case type, hyperparameters, and more.

# %%
generic_model.metadata_taxonomy
# Out:
# data:
# - has_artifact: false
#   key: UseCaseType
#   value: multinomial_classification
# - has_artifact: false
#   key: ArtifactTestResults
#   value: null
# - has_artifact: false
#   key: Algorithm
#   value: None
# - has_artifact: false
#   key: Hyperparameters
#   value: null
# - has_artifact: false
#   key: Framework
#   value: null
# - has_artifact: false
#   key: FrameworkVersion
#   value: null

# %% [markdown]
# <a id='serialize_verify'></a>
# ## Verify
#
# If you modify the `score.py` file that is part of the model artifacts, then you should verify it. The verify step allows you to test those changes without having to deploy the model. The `.verify()` method takes a set of test parameters and performs the prediction by calling the `predict` function in `score.py`. It also runs the `load_model` function.
#
# **Note**: You need to make sure that data passed in to verify is json serializable as data serialization and deserialization is not supported for GenericModel class. However, other frameworks such as `SklearnModel` supports data serialization and deserialization for certain data types such as `Pandas DataFrame`, hence you can directly pass into `Pandas DataFrame` for `SklearnModel`.

# %%
generic_model.verify(X)
# Out:
# Start loading model.pkl from model directory /tmp/tmpmvj5h3xm ...
# Model is successfully loaded.
# {'prediction': [6561, 196, 9, 8836, 1225, 961, 784, 289, 169, 7396]}

# %% [markdown]
# Update the `.summary_status()` method to show that the verify step has been completed:

# %%
generic_model.summary_status()
# Out:
#                                                                             Actions Needed
# Step      Status        Details
# initiate  Done          Initiated the model
# prepare() Done          Generated runtime.yaml
#                         Generated score.py
#                         Serialized model
#           Available     Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Done          Local tested .predict from score.py
# save()    Not Available Conducted Introspect Test
#                         Uploaded artifact to model catalog
# deploy()  UNKNOWN       Deployed the model
# predict() Not Available Called deployment predict endpoint

# %% [markdown]
# <a id='serialize_save'></a>
# ## Save
#
# Once you are satisfied with the performance of the model and have verified that the `score.py` file is working, you save the model to the model catalog using the `.save()` method on the model instance. This step requires authentication provided here. The result is the model OCID which you can view in the UI.

# %%
model_id = generic_model.save(display_name="Demo GenericModel model")
# Out:
# Start loading model.pkl from model directory /tmp/tmpmvj5h3xm ...
# Model is successfully loaded.
# ['.model-ignore', 'input_schema.json', 'model.pkl', 'score.py', 'runtime.yaml', 'output_schema.json']
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:ads.model.datascience_model:the JSON object must be str, bytes or bytearray, not Schema
# WARNING:ads.model.datascience_model:the JSON object must be str, bytes or bytearray, not Schema

# %% [markdown]
# <a id='serialize_deploy'></a>
# ## Deploy
#
# When the model is in the model catalog, you can use the `.deploy()` method of a `GenericModel` object to deploy the model. This method allows you to specify the attributes of the deployment such as the display name, description, instance type and count, the maximum bandwidth, and logging groups. The next cell deploys the model with the default settings, except for the custom display name. The `.deploy()` method returns a `ModelDeployment` object.

# %%
deploy = generic_model.deploy(display_name="Demo GenericModel deployment")
# Out:
# Creating model deployment:   0%|          | [00:00<?, ?it/s]

# %% [markdown]
# After deployment, the `.summary_status()` method shows that the model is `ACTIVE` and the `predict()` method is available.

# %%
generic_model.summary_status()

# %% [markdown]
# <a id='serialize_predict'></a>
# ## Predict
#
# In the <a href='#create'>Create a Generic Model</a> section, you used the `model.predict()` method where `model` is an generic model object. This did inference using the local model. Now that the `GenericModel` model has been deployed, you can do the same thing using similar syntax with the `.predict()` method on a `GenericModel`.
#
# After the deployment is active, you can call the `predict()` on the `GenericModel` object to send request to the deployed endpoint.

# %%
generic_model.predict(X)["prediction"]

# %% [markdown]
# <a id='clean_up'></a>
# # Clean Up
#
# This notebook created a model deployment and a model. This section deletes those resources.
#
# The model deployment must be deleted before the model can be deleted. You use the `.delete_deployment()` method on the `GenericModel` object to do this.

# %%
delete = generic_model.delete_deployment(wait_for_completion=True)

# %% [markdown]
# After the model deployment has been deleted, the `.summary_status()` method shows that the model has been deleted and that the `predict()` method is not available:

# %%
generic_model.summary_status()

# %% [markdown]
# Use the `.delete()` method to delete the model:

# %%
generic_model.delete()

# %% [markdown]
# The next cell removes the model artifacts that were stored on your local drive:

# %%
rmtree(artifact_dir)

# %% [markdown]
# <a id='ref'></a>
# # References
# - [ADS Library Documentation](https://accelerated-data-science.readthedocs.io/en/latest/index.html)
# - [Data Science YouTube Videos](https://www.youtube.com/playlist?list=PLKCk3OyNwIzv6CWMhvqSB_8MLJIZdO80L)
# - [OCI Data Science Documentation](https://docs.cloud.oracle.com/en-us/iaas/data-science/using/data-science.htm)
# - [Oracle Data & AI Blog](https://blogs.oracle.com/datascience/)
# - [Understanding Conda Environments](https://docs.cloud.oracle.com/en-us/iaas/data-science/using/use-notebook-sessions.htm#conda_understand_environments)
# - [Use Resource Manager to Configure Your Tenancy for Data Science](https://docs.cloud.oracle.com/en-us/iaas/data-science/using/orm-configure-tenancy.htm)
# - [`runtime.yaml`](https://docs.content.oci.oracleiaas.com/en-us/iaas/data-science/using/model_runtime_yaml.htm#model_runtime_yaml)
# - [`score.py`](https://docs.content.oci.oracleiaas.com/en-us/iaas/data-science/using/model_score_py.htm#model_score_py)
# - [Model artifact](https://docs.content.oci.oracleiaas.com/en-us/iaas/data-science/using/models_saving_catalog.htm#create-models)
# - [ONNX API Summary](http://onnx.ai/sklearn-onnx/api_summary.html)
